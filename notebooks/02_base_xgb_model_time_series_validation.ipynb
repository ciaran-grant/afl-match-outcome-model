# %% [markdown]
# Model Building - Base Model

# %%
import pandas as pd
import joblib

import warnings

warnings.filterwarnings("ignore")

from afl_match_outcome_model.config import match_summary_file_path
from afl_match_outcome_model.data_preparation.match_summary_preprocessor import MatchSummaryPreprocessor

from afl_match_outcome_model.modelling_data_contract import ModellingDataContract
from afl_match_outcome_model.modelling.hyperparameter_tuning import (
    XGBHyperparameterTuner,
    XGBTimeSeriesCVHyperparameterTuner
)
from afl_match_outcome_model.modelling.supermodel import SuperXGBClassifier
from afl_match_outcome_model.modelling.optuna_xgb_param_grid import OptunaXGBParamGrid

from afl_match_outcome_model.evaluation.model_evaluation import XGBClassifierEvaluator


from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

pd.options.display.max_rows = 100
pd.options.display.max_columns = 999

# %load_ext autoreload
# %autoreload 2
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
RESPONSE = ModellingDataContract.RESPONSE

# %% [markdown]
# Load Data

# %%
data = pd.read_csv(match_summary_file_path)
data = data.sort_values(by = ['Date']).reset_index(drop = True)
data.head()
# Out:
#          Home_Team      Away_Team               Q4_Score  Margin  \
# 0         Richmond      Melbourne    14.10.94 - 13.14.92       2
# 1         Essendon  Port Adelaide    24.12.156 - 8.14.62      94
# 2  North Melbourne     West Coast  16.15.111 - 24.10.154     -43
# 3        Fremantle        Geelong  16.11.107 - 19.15.129     -22
# 4         St Kilda         Sydney   15.10.100 - 21.8.134     -34
#
#    Total Game Score  Home Win      Venue       City                 Date  \
# 0               186       1.0     M.C.G.  Melbourne  2000-03-08 19:40:00
# 1               218       1.0  Docklands  Melbourne  2000-03-09 20:15:00
# 2               265       0.0     M.C.G.  Melbourne  2000-03-10 19:40:00
# 3               236       0.0    Subiaco      Perth  2000-03-11 20:40:00
# 4               234       0.0  Docklands  Melbourne  2000-03-12 19:40:00
#
#    Attendance  Temperature Weather_Type  Year Round_ID  \
# 0       41648          NaN          NaN  2000   200001
# 1       43012          NaN          NaN  2000   200001
# 2       20580          NaN          NaN  2000   200001
# 3       19777          NaN          NaN  2000   200001
# 4       31440          NaN          NaN  2000   200001
#
#                           Match_ID  Season
# 0        200001_Richmond_Melbourne     NaN
# 1     200001_Essendon_PortAdelaide     NaN
# 2  200001_NorthMelbourne_WestCoast     NaN
# 3         200001_Fremantle_Geelong     NaN
# 4            200001_StKilda_Sydney     NaN

# %% [markdown]
# Preprocessing

# %%
match_preprocessor = MatchSummaryPreprocessor(
    categorical_features=['Venue', 'City', 'Opponent' ,'Team'],
    rolling_cols=['Team_Score', 'Opp_Score', 'Team_Goals', 'Opp_Goals'],
    rolling=[1, 3, 5, 10, 20],
    extra_features=['Home']
)
match_preprocessor.fit(data)
# Out:
# MatchSummaryPreprocessor(categorical_features=['Venue', 'City', 'Opponent',
#                                                'Team'],
#                          extra_features=['Home'], rolling=[1, 3, 5, 10, 20],
#                          rolling_cols=['Team_Score', 'Opp_Score', 'Team_Goals',
#                                        'Opp_Goals'])

# %%
X = match_preprocessor.transform(data)
y = match_preprocessor.get_response(data)

# %% [markdown]
# Train Test Split

# %%
X_train = X[X['Year'] < 2022]
X_cal = X[X['Year'] == 2022]
X_test = X[X['Year'] == 2023]

# %%
X_test.head()
# Out:
#       Home  Team_Score_rolling_1  Opp_Score_rolling_1  Team_Goals_rolling_1  \
# 8564     0                  74.0                 75.0                  10.0
# 8565     1                 104.0                106.0                  16.0
# 8566     0                  94.0                 95.0                  14.0
# 8567     1                 133.0                 52.0                  20.0
# 8568     1                  47.0                114.0                   6.0
#
#       Opp_Goals_rolling_1  Team_Score_rolling_3  Opp_Score_rolling_3  \
# 8564                 11.0             76.333333            89.333333
# 8565                 16.0            124.333333            82.666667
# 8566                 14.0             81.666667            77.333333
# 8567                  8.0            110.333333            57.666667
# 8568                 16.0             69.666667           114.333333
#
#       Team_Goals_rolling_3  Opp_Goals_rolling_3  Team_Score_rolling_5  \
# 8564             10.666667            13.000000                  74.8
# 8565             19.000000            12.000000                 117.2
# 8566             11.666667            11.333333                  74.0
# 8567             16.333333             8.333333                 116.2
# 8568              9.666667            16.333333                  70.0
#
#       Opp_Score_rolling_5  Team_Goals_rolling_5  Opp_Goals_rolling_5  \
# 8564                 81.2                  10.6                 11.8
# 8565                 83.2                  17.6                 12.0
# 8566                 76.6                  10.6                 11.0
# 8567                 55.6                  17.2                  8.2
# 8568                115.6                   9.8                 17.0
#
#       Team_Score_rolling_10  Opp_Score_rolling_10  Team_Goals_rolling_10  \
# 8564                   77.0                  76.8                   10.9
# 8565                  103.2                  83.6                   15.2
# 8566                   81.3                  79.7                   12.0
# 8567                  106.7                  62.1                   15.7
# 8568                   66.6                 111.5                    9.5
#
#       Opp_Goals_rolling_10  Team_Score_rolling_20  Opp_Score_rolling_20  \
# 8564                  11.1                  82.70                 77.40
# 8565                  12.1                 100.00                 79.75
# 8566                  11.6                  81.30                 78.15
# 8567                   9.1                  99.90                 61.45
# 8568                  16.2                  60.25                113.00
#
#       Team_Goals_rolling_20  Opp_Goals_rolling_20  Venue_Adelaide Oval  \
# 8564                  11.90                  11.2                False
# 8565                  14.70                  11.4                False
# 8566                  11.80                  11.4                False
# 8567                  14.55                   8.9                False
# 8568                   8.75                  16.5                False
#
#       Venue_Bellerive Oval  Venue_Blacktown  Venue_Carrara  \
# 8564                 False            False          False
# 8565                 False            False          False
# 8566                 False            False          False
# 8567                 False            False          False
# 8568                 False            False          False
#
#       Venue_Cazalys Stadium  Venue_Docklands  Venue_Eureka Stadium  \
# 8564                  False            False                 False
# 8565                  False            False                 False
# 8566                  False            False                 False
# 8567                  False            False                 False
# 8568                  False             True                 False
#
#       Venue_Football Park  Venue_Gabba  Venue_Jiangwan Stadium  \
# 8564                False        False                   False
# 8565                False        False                   False
# 8566                False        False                   False
# 8567                False        False                   False
# 8568                False        False                   False
#
#       Venue_Kardinia Park  Venue_M.C.G.  Venue_Manuka Oval  \
# 8564                False          True              False
# 8565                False          True              False
# 8566                False          True              False
# 8567                False          True              False
# 8568                False         False              False
#
#       Venue_Marrara Oval  Venue_Norwood Oval  Venue_Perth Stadium  \
# 8564               False               False                False
# 8565               False               False                False
# 8566               False               False                False
# 8567               False               False                False
# 8568               False               False                False
#
#       Venue_Princes Park  Venue_Riverway Stadium  Venue_S.C.G.  \
# 8564               False                   False         False
# 8565               False                   False         False
# 8566               False                   False         False
# 8567               False                   False         False
# 8568               False                   False         False
#
#       Venue_Stadium Australia  Venue_Subiaco  Venue_Sydney Showground  \
# 8564                    False          False                    False
# 8565                    False          False                    False
# 8566                    False          False                    False
# 8567                    False          False                    False
# 8568                    False          False                    False
#
#       Venue_Traeger Park  Venue_W.A.C.A.  Venue_Wellington  Venue_York Park  \
# 8564               False           False             False            False
# 8565               False           False             False            False
# 8566               False           False             False            False
# 8567               False           False             False            False
# 8568               False           False             False            False
#
#       City_Adelaide  City_Alice Springs  City_Ballarat  City_Brisbane  \
# 8564          False               False          False          False
# 8565          False               False          False          False
# 8566          False               False          False          False
# 8567          False               False          False          False
# 8568          False               False          False          False
#
#       City_Cairns  City_Canberra  City_Darwin  City_Geelong  City_Gold Coast  \
# 8564        False          False        False         False            False
# 8565        False          False        False         False            False
# 8566        False          False        False         False            False
# 8567        False          False        False         False            False
# 8568        False          False        False         False            False
#
#       City_Hobart  City_Launceston  City_Melbourne  City_Perth  City_Shanghai  \
# 8564        False            False            True       False          False
# 8565        False            False            True       False          False
# 8566        False            False            True       False          False
# 8567        False            False            True       False          False
# 8568        False            False            True       False          False
#
#       City_Sydney  City_Townsville  City_Wellington  Opponent_Adelaide  \
# 8564        False            False            False              False
# 8565        False            False            False              False
# 8566        False            False            False              False
# 8567        False            False            False              False
# 8568        False            False            False              False
#
#       Opponent_Brisbane Lions  Opponent_Carlton  Opponent_Collingwood  \
# 8564                    False             False                 False
# 8565                    False              True                 False
# 8566                    False             False                 False
# 8567                    False             False                  True
# 8568                    False             False                 False
#
#       Opponent_Essendon  Opponent_Fremantle  Opponent_Geelong  \
# 8564              False               False             False
# 8565              False               False             False
# 8566              False               False              True
# 8567              False               False             False
# 8568              False               False             False
#
#       Opponent_Gold Coast  Opponent_Greater Western Sydney  Opponent_Hawthorn  \
# 8564                False                            False              False
# 8565                False                            False              False
# 8566                False                            False              False
# 8567                False                            False              False
# 8568                False                            False              False
#
#       Opponent_Melbourne  Opponent_North Melbourne  Opponent_Port Adelaide  \
# 8564               False                     False                   False
# 8565               False                     False                   False
# 8566               False                     False                   False
# 8567               False                     False                   False
# 8568               False                     False                   False
#
#       Opponent_Richmond  Opponent_St Kilda  Opponent_Sydney  \
# 8564               True              False            False
# 8565              False              False            False
# 8566              False              False            False
# 8567              False              False            False
# 8568              False              False            False
#
#       Opponent_West Coast  Opponent_Western Bulldogs  Team_Adelaide  \
# 8564                False                      False          False
# 8565                False                      False          False
# 8566                False                      False          False
# 8567                False                      False          False
# 8568                 True                      False          False
#
#       Team_Brisbane Lions  Team_Carlton  Team_Collingwood  Team_Essendon  \
# 8564                False          True             False          False
# 8565                False         False             False          False
# 8566                False         False              True          False
# 8567                False         False             False          False
# 8568                False         False             False          False
#
#       Team_Fremantle  Team_Geelong  Team_Gold Coast  \
# 8564           False         False            False
# 8565           False         False            False
# 8566           False         False            False
# 8567           False          True            False
# 8568           False         False            False
#
#       Team_Greater Western Sydney  Team_Hawthorn  Team_Melbourne  \
# 8564                        False          False           False
# 8565                        False          False           False
# 8566                        False          False           False
# 8567                        False          False           False
# 8568                        False          False           False
#
#       Team_North Melbourne  Team_Port Adelaide  Team_Richmond  Team_St Kilda  \
# 8564                 False               False          False          False
# 8565                 False               False           True          False
# 8566                 False               False          False          False
# 8567                 False               False          False          False
# 8568                  True               False          False          False
#
#       Team_Sydney  Team_West Coast  Team_Western Bulldogs  Day  Month  Year
# 8564        False            False                  False   16      3  2023
# 8565        False            False                  False   16      3  2023
# 8566        False            False                  False   17      3  2023
# 8567        False            False                  False   17      3  2023
# 8568        False            False                  False   18      3  2023

# %%
y_train = y.loc[X_train.index]
y_cal = y.loc[X_cal.index]
y_test = y.loc[X_test.index]

# %% [markdown]
# Optuna Hyperparameter Tuning Class - HyperParameterTuner & XGBHyperparameterTuner

# %% [markdown]
# Time Series Cross Validation

# %%
xgb_tuner = XGBTimeSeriesCVHyperparameterTuner(
    X_train, y_train, monotonicity_constraints={}
)

# %%
xgb_tuner.tune_hyperparameters()
# Out:
# [I 2024-01-13 13:18:46,440] A new study created in memory with name: no-name-c80b361b-d394-4644-b0c7-c0357c5008a4
# [I 2024-01-13 13:18:47,473] Trial 0 finished with value: 0.6859379933375302 and parameters: {'max_depth': 2, 'min_child_weight': 13, 'eta': 0.581696176983168, 'gamma': 0.4771180375020407, 'lambda': 0.06736887997506116, 'alpha': 0.011793802392969644, 'subsample': 0.2979836246628349, 'colsample_bytree': 0.7265998761764365}. Best is trial 0 with value: 0.6859379933375302.
# [I 2024-01-13 13:18:48,591] Trial 1 finished with value: 0.683801338812262 and parameters: {'max_depth': 7, 'min_child_weight': 88, 'eta': 0.06399100705681311, 'gamma': 0.000303572401879148, 'lambda': 0.004486525054031236, 'alpha': 0.14694936551435991, 'subsample': 0.8419273209978861, 'colsample_bytree': 0.28121276773887194}. Best is trial 1 with value: 0.683801338812262.
# [I 2024-01-13 13:18:49,771] Trial 2 finished with value: 0.6916872116579282 and parameters: {'max_depth': 11, 'min_child_weight': 40, 'eta': 0.46715978062259805, 'gamma': 0.0033948021421364425, 'lambda': 0.43454713287752034, 'alpha': 1.5546286819950697, 'subsample': 0.4174579148619285, 'colsample_bytree': 0.3290410267844974}. Best is trial 1 with value: 0.683801338812262.
# [I 2024-01-13 13:18:50,802] Trial 3 finished with value: 0.688073787608035 and parameters: {'max_depth': 12, 'min_child_weight': 85, 'eta': 0.042732619439085705, 'gamma': 0.003329209949939939, 'lambda': 0.11019655891893292, 'alpha': 0.17076362194569866, 'subsample': 0.4125774932906088, 'colsample_bytree': 0.27213653022466167}. Best is trial 1 with value: 0.683801338812262.
# [I 2024-01-13 13:18:52,152] Trial 4 finished with value: 0.7623376727127809 and parameters: {'max_depth': 9, 'min_child_weight': 26, 'eta': 0.9663376591392113, 'gamma': 0.015762097729053293, 'lambda': 0.0007446984326393393, 'alpha': 0.056203273395756585, 'subsample': 0.7800589959272146, 'colsample_bytree': 0.3985710068649021}. Best is trial 1 with value: 0.683801338812262.
# [I 2024-01-13 13:18:53,235] Trial 5 finished with value: 0.6770075108311606 and parameters: {'max_depth': 14, 'min_child_weight': 69, 'eta': 0.10225114918471212, 'gamma': 0.0003548331623149567, 'lambda': 0.03063506686193182, 'alpha': 0.010788897945857103, 'subsample': 0.6249737164526339, 'colsample_bytree': 0.4105024092360886}. Best is trial 5 with value: 0.6770075108311606.
# [I 2024-01-13 13:18:54,257] Trial 6 finished with value: 0.6801884097018227 and parameters: {'max_depth': 8, 'min_child_weight': 78, 'eta': 0.32714439496548636, 'gamma': 2.293632991989898, 'lambda': 0.07699300617914384, 'alpha': 0.09369615500502963, 'subsample': 0.4434529371458036, 'colsample_bytree': 0.6523041325664751}. Best is trial 5 with value: 0.6770075108311606.
# [I 2024-01-13 13:18:55,326] Trial 7 finished with value: 0.6911920116046244 and parameters: {'max_depth': 17, 'min_child_weight': 83, 'eta': 0.011428405710484266, 'gamma': 0.0015527357782068277, 'lambda': 0.23298397761738657, 'alpha': 0.15461334401126858, 'subsample': 0.7855569477550064, 'colsample_bytree': 0.7150476959162093}. Best is trial 5 with value: 0.6770075108311606.
# [I 2024-01-13 13:18:56,299] Trial 8 finished with value: 0.6868390270126397 and parameters: {'max_depth': 6, 'min_child_weight': 70, 'eta': 0.41991313078461084, 'gamma': 0.00011600800034997278, 'lambda': 1.7035740461539606, 'alpha': 0.03643615266296906, 'subsample': 0.7906893590443844, 'colsample_bytree': 0.6866831291726286}. Best is trial 5 with value: 0.6770075108311606.
# [I 2024-01-13 13:18:57,327] Trial 9 finished with value: 0.6821838486640935 and parameters: {'max_depth': 5, 'min_child_weight': 19, 'eta': 0.04914526193355398, 'gamma': 0.00013861796155651695, 'lambda': 0.0016136251522773353, 'alpha': 0.0009740300603593633, 'subsample': 0.6958464535759946, 'colsample_bytree': 0.8240677280407351}. Best is trial 5 with value: 0.6770075108311606.
# [I 2024-01-13 13:18:58,551] Trial 10 finished with value: 0.6763423751345907 and parameters: {'max_depth': 20, 'min_child_weight': 57, 'eta': 0.16968889547720342, 'gamma': 0.10404058253431746, 'lambda': 0.0001545139563124957, 'alpha': 0.00019515894159772984, 'subsample': 0.6032487068025971, 'colsample_bytree': 0.4755734084543064}. Best is trial 10 with value: 0.6763423751345907.
# [I 2024-01-13 13:18:59,763] Trial 11 finished with value: 0.6803306065634338 and parameters: {'max_depth': 20, 'min_child_weight': 57, 'eta': 0.17132698994545684, 'gamma': 0.10482181544331562, 'lambda': 0.008134616371407635, 'alpha': 0.00014427497616744425, 'subsample': 0.613362768799721, 'colsample_bytree': 0.48574933466626596}. Best is trial 10 with value: 0.6763423751345907.
# [I 2024-01-13 13:19:00,851] Trial 12 finished with value: 0.6763181303243548 and parameters: {'max_depth': 15, 'min_child_weight': 58, 'eta': 0.14087814129877582, 'gamma': 0.06916217915680004, 'lambda': 0.00010892878070368005, 'alpha': 0.0019361755451160036, 'subsample': 0.5497644922354724, 'colsample_bytree': 0.49986314315353236}. Best is trial 12 with value: 0.6763181303243548.
. Best is trial 77 with value: 0.6581293908990301.
# [I 2024-01-13 13:20:49,842] Trial 98 finished with value: 0.7474859384222394 and parameters: {'max_depth': 10, 'min_child_weight': 11, 'eta': 0.6295374322833115, 'gamma': 0.00016822625984640806, 'lambda': 0.067036914776581, 'alpha': 0.0030344368110984, 'subsample': 0.7815335726628311, 'colsample_bytree': 0.5704873781961894}. Best is trial 77 with value: 0.6581293908990301.
# [I 2024-01-13 13:20:51,005] Trial 99 finished with value: 0.6743733167160032 and parameters: {'max_depth': 3, 'min_child_weight': 8, 'eta': 0.539185722323518, 'gamma': 0.11708796333839702, 'lambda': 0.10409171132046141, 'alpha': 0.22546661236786475, 'subsample': 0.6338537954106293, 'colsample_bytree': 0.8829034580152257}. Best is trial 77 with value: 0.6581293908990301.
# Number of finished trials:  100
# Best trial:
#   Value: 0.6581293908990301
#   Params:
#     max_depth: 5
#     min_child_weight: 8
#     eta: 0.18399355135844608
#     gamma: 0.19904588213372093
#     lambda: 0.03141310651045348
#     alpha: 0.0013921946107717223
#     subsample: 0.8386814508349824
#     colsample_bytree: 0.6112463105522565

# %%
params = xgb_tuner.get_best_params()
params
# Out:
# {'max_depth': 5,
#  'min_child_weight': 8,
#  'eta': 0.18399355135844608,
#  'gamma': 0.19904588213372093,
#  'lambda': 0.03141310651045348,
#  'alpha': 0.0013921946107717223,
#  'subsample': 0.8386814508349824,
#  'colsample_bytree': 0.6112463105522565}

# %% [markdown]
# Training Model - SuperXGBClassifier class for training and predictions

# %%
params["objective"] = OptunaXGBParamGrid.error
params["num_rounds"] = 1000
params["early_stopping_rounds"] = 10
params["verbosity"] = 1
params["monotone_constraints"] = {}

# %%
super_xgb = SuperXGBClassifier(
    X_train=X_train, y_train=y_train,
    X_test=X_test, y_test=y_test,
    X_cal=X_cal, y_cal=y_cal,
    params=params
)

# %%
super_xgb.fit()
# Out:
# [0]	validation_0-logloss:0.67485	validation_1-logloss:0.67943
# [1]	validation_0-logloss:0.66427	validation_1-logloss:0.67550
# [2]	validation_0-logloss:0.65339	validation_1-logloss:0.66877
# [3]	validation_0-logloss:0.64677	validation_1-logloss:0.66538
# [4]	validation_0-logloss:0.64021	validation_1-logloss:0.66464
# [5]	validation_0-logloss:0.63372	validation_1-logloss:0.66076
# [6]	validation_0-logloss:0.62975	validation_1-logloss:0.65969
# [7]	validation_0-logloss:0.62454	validation_1-logloss:0.65984
# [8]	validation_0-logloss:0.61974	validation_1-logloss:0.66182
# [9]	validation_0-logloss:0.61541	validation_1-logloss:0.66065
# [10]	validation_0-logloss:0.61228	validation_1-logloss:0.66116
# [11]	validation_0-logloss:0.60910	validation_1-logloss:0.66278
# [12]	validation_0-logloss:0.60686	validation_1-logloss:0.66391
# [13]	validation_0-logloss:0.60423	validation_1-logloss:0.66431
# [14]	validation_0-logloss:0.60070	validation_1-logloss:0.66438
# [15]	validation_0-logloss:0.59779	validation_1-logloss:0.66163
# [16]	validation_0-logloss:0.59453	validation_1-logloss:0.66209

# %%
super_xgb.calibrate()

# %%
super_xgb.xgb_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6112463105522565, device=None,
#               early_stopping_rounds=10, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.19904588213372093,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.18399355135844608,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=8, missing=nan, monotone_constraints={},
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
preds = super_xgb.predict(X)
train_preds = super_xgb.predict(X_train)
test_preds = super_xgb.predict(X_test)

# %%
preds = super_xgb.predict(X)
train_preds = super_xgb.predict(X_train)
cal_preds = super_xgb.predict(X_cal)
test_preds = super_xgb.predict(X_test)

# %%
probas = super_xgb.predict_proba(X)[:, 1]
train_probas = super_xgb.predict_proba(X_train)[:, 1]
test_probas = super_xgb.predict_proba(X_test)[:, 1]
cal_probas = super_xgb.predict_proba(X_cal)[:, 1]

# %%
cal_probas = super_xgb.predict_proba(X, calibrate=True)
train_cal_probas = super_xgb.predict_proba(X_train, calibrate=True)
test_cal_probas = super_xgb.predict_proba(X_test, calibrate=True)
cal_cal_probas = super_xgb.predict_proba(X_cal, calibrate=True)

# %% [markdown]
# Check Average Predictions

# %%
y.mean(), probas.mean(), cal_probas.mean()
# Out:
# (0.5016688918558078, 0.50313926, 0.4928303628938938)

# %%
y_train.mean(), train_probas.mean(), train_cal_probas.mean()
# Out:
# (0.501840490797546, 0.5024808, 0.4917362854731698)

# %%
y_test.mean(), test_probas.mean(), test_cal_probas.mean()
# Out:
# (0.5, 0.5113648, 0.5068604379891896)

# %%
y_cal.mean(), cal_probas.mean(), cal_cal_probas.mean()
# Out:
# (0.5, 0.4928303628938938, 0.4999993946293906)

# %% [markdown]
# Model Evaluation

# %%
training_data = pd.concat([X_train, y_train], axis=1)
training_data["xgb_preds"] = train_preds
training_data["xgb_probas"] = train_probas
training_data["xgb_cal_probas"] = train_cal_probas
training_data['baseline'] = y_train.mean()
training_data['baseline_label'] = 1

train_xgb_evals = XGBClassifierEvaluator(
    model=super_xgb.xgb_model,
    data=training_data,
    actual_name=RESPONSE,
    expected_name="xgb_cal_probas",
    expected_label_name="xgb_preds",
    compare_name="baseline",
    compare_label_name="baseline_label"
)

# %%
test_data = pd.concat([X_test, y_test], axis=1)
test_data["xgb_preds"] = test_preds
test_data["xgb_probas"] = test_probas
test_data["xgb_cal_probas"] = test_cal_probas
test_data['baseline'] = y_train.mean()
test_data['baseline_label'] = 1

test_xgb_evals = XGBClassifierEvaluator(
    model=super_xgb.xgb_model,
    data=test_data,
    actual_name=RESPONSE,
    expected_name="xgb_cal_probas",
    expected_label_name="xgb_preds",
    compare_name="baseline",
    compare_label_name="baseline_label"
)

baseline_xgb_evals = XGBClassifierEvaluator(
    model=super_xgb.xgb_model,
    data=test_data,
    actual_name=RESPONSE,
    expected_name="baseline",
    expected_label_name="baseline_label",
)

# %% [markdown]
# Model Averages

# %%
test_data[[RESPONSE, "xgb_probas", "xgb_cal_probas", "baseline_label", "baseline"]].describe()
# Out:
#            Result  xgb_probas  xgb_cal_probas  baseline_label      baseline
# count  424.000000  424.000000      424.000000           424.0  4.240000e+02
# mean     0.500000    0.511365        0.506860             1.0  5.018405e-01
# std      0.500591    0.107053        0.162875             0.0  1.111535e-16
# min      0.000000    0.211562        0.108304             1.0  5.018405e-01
# 25%      0.000000    0.457897        0.413599             1.0  5.018405e-01
# 50%      0.500000    0.528272        0.529138             1.0  5.018405e-01
# 75%      1.000000    0.580352        0.616412             1.0  5.018405e-01
# max      1.000000    0.745946        0.859384             1.0  5.018405e-01

# %% [markdown]
# Check Average Predictions

# %%
y.mean(), probas.mean(), cal_probas.mean()
# Out:
# (0.5016688918558078, 0.50313926, 0.4928303628938938)

# %%
y_train.mean(), train_probas.mean(), train_cal_probas.mean()
# Out:
# (0.501840490797546, 0.5024808, 0.4917362854731698)

# %%
y_test.mean(), test_probas.mean(), test_cal_probas.mean()
# Out:
# (0.5, 0.5113648, 0.5068604379891896)

# %%
y_cal.mean(), cal_probas.mean(), cal_cal_probas.mean()
# Out:
# (0.5, 0.4928303628938938, 0.4999993946293906)

# %% [markdown]
# Model Evaluation

# %%
training_data = pd.concat([X_train, y_train], axis=1)
training_data["xgb_preds"] = train_preds
training_data["xgb_probas"] = train_probas
training_data["xgb_cal_probas"] = train_cal_probas
training_data['baseline'] = y_train.mean()
training_data['baseline_label'] = 1

train_xgb_evals = XGBClassifierEvaluator(
    model=super_xgb.xgb_model,
    data=training_data,
    actual_name=RESPONSE,
    expected_name="xgb_cal_probas",
    expected_label_name="xgb_preds",
    compare_name="baseline",
    compare_label_name="baseline_label"
)

# %%
test_data = pd.concat([X_test, y_test], axis=1)
test_data["xgb_preds"] = test_preds
test_data["xgb_probas"] = test_probas
test_data["xgb_cal_probas"] = test_cal_probas
test_data['baseline'] = y_train.mean()
test_data['baseline_label'] = 1

test_xgb_evals = XGBClassifierEvaluator(
    model=super_xgb.xgb_model,
    data=test_data,
    actual_name=RESPONSE,
    expected_name="xgb_cal_probas",
    expected_label_name="xgb_preds",
    compare_name="baseline",
    compare_label_name="baseline_label"
)

baseline_xgb_evals = XGBClassifierEvaluator(
    model=super_xgb.xgb_model,
    data=test_data,
    actual_name=RESPONSE,
    expected_name="baseline",
    expected_label_name="baseline_label",
)

# %% [markdown]
# Model Averages

# %%
test_data[[RESPONSE, "xgb_probas", "xgb_cal_probas", "baseline_label", "baseline"]].describe()
# Out:
#            Result  xgb_probas  xgb_cal_probas  baseline_label      baseline
# count  424.000000  424.000000      424.000000           424.0  4.240000e+02
# mean     0.500000    0.511365        0.506860             1.0  5.018405e-01
# std      0.500591    0.107053        0.162875             0.0  1.111535e-16
# min      0.000000    0.211562        0.108304             1.0  5.018405e-01
# 25%      0.000000    0.457897        0.413599             1.0  5.018405e-01
# 50%      0.500000    0.528272        0.529138             1.0  5.018405e-01
# 75%      1.000000    0.580352        0.616412             1.0  5.018405e-01
# max      1.000000    0.745946        0.859384             1.0  5.018405e-01

# %% [markdown]
# Model Metrics (for probabilities, mainly want calibration curve, logloss and brier score loss)

# %%
test_xgb_evals.get_log_loss()
# Out:
# Expected Log-Loss: 	0.6619
# Compare Log-Loss: 	0.6932
# (0.6618998343341931, 0.6618998343341931)

# %%
test_xgb_evals.get_brier_score_loss()
# Out:
# Expected Brier Score: 	0.2341
# Compare Brier Score: 	0.2500
# (0.23412296281930736, 0.25000338740637584)

# %%
train_xgb_evals.display_calibration_curve(nbins=20)
test_xgb_evals.display_calibration_curve(nbins=20)

# %%
test_xgb_evals.get_accuracy(), test_xgb_evals.get_recall(), test_xgb_evals.get_precision(), test_xgb_evals.get_f1_score()
# Out:
# Expected Accuracy: 	0.6132
# Compare Accuracy: 	0.5000
# Expected Recall: 	0.7311
# Compare Recall: 	1.0000
# Expected Precision: 	0.5916
# Compare Precision: 	0.5000
# Expected F1 Score: 	0.6540
# Compare F1 Score: 	0.6667
# ((0.6132075471698113, 0.5),
#  (0.7311320754716981, 1.0),
#  (0.5916030534351145, 0.5),
#  (0.6540084388185655, 0.6666666666666666))

# %%
baseline_xgb_evals.get_confusion_matrix(), test_xgb_evals.get_confusion_matrix()
# Out:
# (array([[  0, 212],
#         [  0, 212]]),
#  array([[105, 107],
#         [ 57, 155]]))

# %%
baseline_xgb_evals.plot_roc_curve()
test_xgb_evals.plot_roc_curve()

# %%
baseline_xgb_evals.plot_prauc_curve()
test_xgb_evals.plot_prauc_curve()

# %%
test_xgb_evals.plot_double_lift_chart()

# %% [markdown]
# Plots

# %%
test_xgb_evals.plot_feature_importance(
    max_num_features=10, importance_type="total_gain"
)

# %%
test_xgb_evals.plot_shap_summary_plot(sample=len(X_test))

# %%
top_features = test_xgb_evals.get_ranked_feature_importance()
top_10_features = top_features[:10]
top_10_features
# Out:
# ['Opp_Score_rolling_20',
#  'Home',
#  'Team_Score_rolling_20',
#  'Opp_Score_rolling_10',
#  'Team_Score_rolling_10',
#  'Opponent_Gold Coast',
#  'Team_Score_rolling_5',
#  'Opponent_Carlton',
#  'Opp_Goals_rolling_20',
#  'Team_Goals_rolling_20']

# %%
for col in top_10_features:
    # train_xgb_evals.plot_pdp([col])
    test_xgb_evals.plot_pdp([col])

# %%
# for col in top_10_features:
#     train_xgb_evals.plot_ice([col])
#     test_xgb_evals.plot_ice([col])

# %%
for col in top_10_features:
    train_xgb_evals.plot_feature_ave(col)
    test_xgb_evals.plot_feature_ave(col)

# %% [markdown]
# Export and Save Pipeline

# %%
joblib.dump(super_xgb, "/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-match-outcome-model/model_outputs/time_series_base_match_outcome_xgb.joblib")
joblib.dump(match_preprocessor, "/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-match-outcome-model/model_outputs/time_series_base_match_outcome_match_preprocessor.joblib")
# Out:
# ['/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-match-outcome-model/model_outputs/time_series_base_match_outcome_match_preprocessor.joblib']

# %%
pipeline = Pipeline([
    ('preprocessor', match_preprocessor),
    ('model', super_xgb)
])
pipeline.predict_proba(data, calibrate=True).mean(), pipeline.predict_proba(data, calibrate=False).mean()
# Out:
# (0.4928303628938938, 0.5)

# %%
joblib.dump(pipeline, "/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-match-outcome-model/model_outputs/time_series_base_match_outcome_pipeline.joblib")
# Out:
# ['/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-match-outcome-model/model_outputs/time_series_base_match_outcome_pipeline.joblib']
